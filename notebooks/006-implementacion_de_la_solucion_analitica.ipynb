# %% [markdown]
# # implementacion de la solución analítica
#
# **Fecha:** 2026-04-28

# %% [markdown]
# ## Implementación del método de Fujita

# %%
import numpy as np

# %%
"""
To-do
- [ ] definir F (lambda_0_sr)
- [ ] definir Lambda_r
- [ ] definir Lambda_r_s1
- [ ]
- [ ]
- [ ]
- [ ]
- [ ]
- [ ]
- [ ]
"""


def lambda_0_sr(r, r_1, r_2, r_3, r_4, Epsilon, y_r, k_r):
    A = 1/np.sqrt(1 - Epsilon**2)
    B = 2/np.sqrt((r_1 - r_3) * (r_2 - r_4))
    C = F(np.arcsin(y_r), k_r)

    return A*B*C

def lambda_sr(r):
    A = lambda_0_sr(r) - Lambda_r_s1
    B = -lambda_0_sr(r) + Lambda_r - Lambda_r_s1
    C = lambda_0_sr(r) + Lambda_r - Lambda_r_s1
