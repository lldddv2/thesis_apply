# %% [markdown]
# # Nuevo integrador
#
# **Fecha:** 2026-03-24

# %%
# !pip install -e ../../relatipy
# Out:
# Obtaining file:///Users/ldiaz/Documents/Documentos/otros/relatipy
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: sympy in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from relatipy==0.4.2) (1.14.0)
# Requirement already satisfied: numpy in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from relatipy==0.4.2) (2.4.4)
# Requirement already satisfied: scipy in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from relatipy==0.4.2) (1.17.1)
# Requirement already satisfied: plotly in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from relatipy==0.4.2) (6.7.0)
# Requirement already satisfied: einsteinpy in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from relatipy==0.4.2) (0.4.0)
# Requirement already satisfied: pytest>=9.0.2 in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from relatipy==0.4.2) (9.0.3)
# Requirement already satisfied: astropy>=6 in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from relatipy==0.4.2) (7.2.0)
# Requirement already satisfied: spiceypy>=8.0.2 in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from relatipy==0.4.2) (8.1.0)
# Requirement already satisfied: matplotlib>=3.10.8 in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from relatipy==0.4.2) (3.10.9)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from relatipy==0.4.2) (5.10.4)
# Requirement already satisfied: pandas>=2.3.3 in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from relatipy==0.4.2) (3.0.3)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from astropy>=6->relatipy==0.4.2) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.10.27.0.39.10 in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from astropy>=6->relatipy==0.4.2) (0.2026.5.11.1.8.52)
# Requirement already satisfied: PyYAML>=6.0.0 in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from astropy>=6->relatipy==0.4.2) (6.0.3)
# Requirement already satisfied: packaging>=22.0.0 in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from astropy>=6->relatipy==0.4.2) (26.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from matplotlib>=3.10.8->relatipy==0.4.2) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from matplotlib>=3.10.8->relatipy==0.4.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from matplotlib>=3.10.8->relatipy==0.4.2) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from matplotlib>=3.10.8->relatipy==0.4.2) (1.5.0)
# Requirement already satisfied: pillow>=8 in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from matplotlib>=3.10.8->relatipy==0.4.2) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from matplotlib>=3.10.8->relatipy==0.4.2) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from matplotlib>=3.10.8->relatipy==0.4.2) (2.9.0.post0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from nbformat>=4.2.0->relatipy==0.4.2) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from nbformat>=4.2.0->relatipy==0.4.2) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from nbformat>=4.2.0->relatipy==0.4.2) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from nbformat>=4.2.0->relatipy==0.4.2) (5.15.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->relatipy==0.4.2) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->relatipy==0.4.2) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->relatipy==0.4.2) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->relatipy==0.4.2) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->relatipy==0.4.2) (4.9.6)
# Requirement already satisfied: iniconfig>=1.0.1 in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from pytest>=9.0.2->relatipy==0.4.2) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from pytest>=9.0.2->relatipy==0.4.2) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from pytest>=9.0.2->relatipy==0.4.2) (2.20.0)
# Requirement already satisfied: six>=1.5 in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->relatipy==0.4.2) (1.17.0)
# Requirement already satisfied: numba!=0.49.0,>=0.46 in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from einsteinpy->relatipy==0.4.2) (0.65.1)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from numba!=0.49.0,>=0.46->einsteinpy->relatipy==0.4.2) (0.47.0)
# Requirement already satisfied: narwhals>=1.15.1 in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from plotly->relatipy==0.4.2) (2.21.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/ldiaz/Documents/Documentos/otros/thesis_apply/.venv/lib/python3.14/site-packages (from sympy->relatipy==0.4.2) (1.3.0)
# Building wheels for collected packages: relatipy
#   Building editable for relatipy (pyproject.toml) ... done
#   Created wheel for relatipy: filename=relatipy-0.4.2-0.editable-cp314-cp314-macosx_26_0_arm64.whl size=2100 sha256=e6e5df01f883a071a5937cb3b5af02513ec272f5d2a1eb6a185b61090a19b636
#   Stored in directory: /private/var/folders/8g/jy3rvzr50kv5w6g24cxmq6kc0000gp/T/pip-ephem-wheel-cache-uzaob8dj/wheels/fc/5b/f0/21215a20fa53e825ba695a0a60ab2d26346f3989cd1d5e931d
# Successfully built relatipy
# Installing collected packages: relatipy
#   Attempting uninstall: relatipy
#     Found existing installation: relatipy 0.4.2
#     Uninstalling relatipy-0.4.2:
#       Successfully uninstalled relatipy-0.4.2
# Successfully installed relatipy-0.4.2

# %%
import relatipy.numeric as rn
import relatipy.visualization as vis
import numpy as np
import matplotlib.pyplot as plt

# %%
kerr = rn.metrics.Kerr(a=0.5, mass=1)

# %%
isco_prograde = kerr.isco_prograde
isco_retrograde = kerr.isco_retrograde
R_s = kerr.R_s

# %%
ics = rn.coordinates.OrbitalElements(
    t=0,
    a=5*isco_prograde,
    e=0,
    inc=0,
    Omega=0,
    omega=0,
    f=0,
    mass=1
)
P = ics._get_period()
print(P)
# Out:
# 611.7974561486187

# %%
taus = (0, 500*P)
path = kerr.geodesic.get_path(ics, taus, integrator="Radau2")
from relatipy.visualization._3D.plot_black_hole import PlotKerr
plot = PlotKerr(kerr)
plot.add_path(path, label="orbit")
plot.plot().show()

# # save ../figures/003-integradores_a_largo_plazo/orbit.png as plotly html
# plot.plot().write_html("../figures/003-integradores_a_largo_plazo/orbit.html")

# %%
from relatipy.visualization._2D import SciSubplot

# Misma configuración que en 003: a = 100*R_s, inclinaciones 0°…90°,
# ventana temporal 500 períodos de la órbita de referencia (inc=10).
ics_ref = rn.coordinates.OrbitalElements(
    t=0,
    a=100 * R_s,
    e=0,
    inc=10,
    Omega=0,
    omega=0,
    f=0,
    mass=1,
)
P_ref = ics_ref._get_period()
taus = (0, 500 * P_ref)

N = 10

ics_ = [
    rn.coordinates.OrbitalElements(
        t=0,
        a=100 * R_s,
        e=0,
        inc=inc,
        Omega=0,
        omega=0,
        f=0,
        mass=1,
    )
    for inc in [(40/N) * i for i in range(0, N+1)]
]
Ps = [ics_i._get_period() for ics_i in ics_]
paths = [
    kerr.geodesic.get_path(ics_i, taus, integrator="Yoshida6").convert_to(
        "BoyerLindquist", a=kerr.a
    )
    for ics_i in ics_
]


def plot_errors(workspace, path, P, taus, label=""):
    fig, axs = workspace.fig, workspace.axs

    muestreo = 1000

    times = path[0][::muestreo] / P
    get_absolute_error = lambda x: abs((x - x[0]) / x[0]) * 100

    labels = [
        {"values": lambda p: p._get_Q(kerr)[::muestreo], "ax": 0, "ylabel": r"Relative error in $Q$ (%)"},
        {"values": lambda p: p._get_E(kerr)[::muestreo], "ax": 1, "ylabel": r"Relative error in $E$ (%)"},
        {"values": lambda p: p._get_Lz(kerr)[::muestreo], "ax": 2, "ylabel": r"Relative error in $L_z$ (%)"},
    ]
    for i, l in enumerate(labels):
        values = l["values"](path)
        errors = get_absolute_error(values)

        axs[i].plot(times, errors, ".", label=label if i == 0 else "")

        axs[i].set_xlim(taus[0] / P, taus[1] / P)
        axs[i].set_ylabel(l["ylabel"])
        if i == 2:
            axs[i].set_xlabel("Time (periods)")

    axs[0].set_xticklabels([])
    axs[1].set_xticklabels([])
    fig.subplots_adjust(hspace=0)


workspace = SciSubplot(figsize=(5, 6), subplot=(3, 1))
fig, axs = workspace.fig, workspace.axs

for i, path in enumerate(paths[:-1]):
    plot_errors(workspace, path, Ps[i], taus, f"inc={ics_[i].inc}")

handles, labels_ = axs[0].get_legend_handles_labels()
unique = dict(zip(labels_, handles))
fig.legend(
    unique.values(),
    unique.keys(),
    loc="center left",
    bbox_to_anchor=(0.70, 0.5),
    frameon=False,
    borderaxespad=0,
    labelspacing=0.5,
    handletextpad=0.1,
    ncol=1,
    fontsize="medium",
)
fig.subplots_adjust(right=0.7)

import os

# os.makedirs("../figures/004-nuevo_integrador", exist_ok=True)
# fig.savefig("../figures/004-nuevo_integrador/errors_Q_E_Lz_Yoshida6_sin_projection.png")

# %%
from relatipy.visualization._2D import SciSubplot

# Misma configuración que en 003: a = 100*R_s, inclinaciones 0°…90°,
# ventana temporal 500 períodos de la órbita de referencia (inc=10).
ics_ref = rn.coordinates.OrbitalElements(
    t=0,
    a=100 * R_s,
    e=0,
    inc=10,
    Omega=0,
    omega=0,
    f=0,
    mass=1,
)
P_ref = ics_ref._get_period()
taus = (0, 500 * P_ref)

N = 9

ics_ = [
    rn.coordinates.OrbitalElements(
        t=0,
        a=100 * R_s,
        e=0,
        inc=inc,
        Omega=0,
        omega=0,
        f=0,
        mass=1,
    )
    for inc in [(90/N) * (i) for i in range(0, N+1)]
]
Ps = [ics_i._get_period() for ics_i in ics_]
paths = [
    kerr.geodesic.get_path(ics_i, taus, integrator="Radau2").convert_to(
        "BoyerLindquist", a=kerr.a
    )
    for ics_i in ics_
]


def plot_errors(workspace, path, P, taus, label=""):
    fig, axs = workspace.fig, workspace.axs

    muestreo = 1000

    times = path[0][::muestreo] / P
    get_absolute_error = lambda x: abs((x - x[0]) / x[0]) * 100

    labels = [
        {"values": lambda p: p._get_Q(kerr)[::muestreo], "ax": 0, "ylabel": r"Relative error in $Q$ (%)"},
        {"values": lambda p: p._get_E(kerr)[::muestreo], "ax": 1, "ylabel": r"Relative error in $E$ (%)"},
        {"values": lambda p: p._get_Lz(kerr)[::muestreo], "ax": 2, "ylabel": r"Relative error in $L_z$ (%)"},
    ]
    for i, l in enumerate(labels):
        values = l["values"](path)
        errors = get_absolute_error(values)

        axs[i].plot(times, errors, ".", label=label if i == 0 else "", markersize=2)

        axs[i].set_xlim(taus[0] / P, taus[1] / P)
        axs[i].set_ylabel(l["ylabel"])
        if i == 2:
            axs[i].set_xlabel("Time (periods)")

    axs[0].set_xticklabels([])
    axs[1].set_xticklabels([])
    fig.subplots_adjust(hspace=0)


workspace = SciSubplot(figsize=(5, 6), subplot=(3, 1))
fig, axs = workspace.fig, workspace.axs

for i, path in enumerate(paths[:-1]):
    plot_errors(workspace, path, Ps[i], taus, f"inc={ics_[i].inc}")

handles, labels_ = axs[0].get_legend_handles_labels()
unique = dict(zip(labels_, handles))
fig.legend(
    unique.values(),
    unique.keys(),
    loc="center left",
    bbox_to_anchor=(0.70, 0.5),
    frameon=False,
    borderaxespad=0,
    labelspacing=0.5,
    handletextpad=0.1,
    ncol=1,
    fontsize="medium",
)
fig.subplots_adjust(right=0.7)

axs[0].set_yscale("log")
# axs[1].set_yscale("log")
# axs[2].set_yscale("log")

import os

# os.makedirs("../figures/004-nuevo_integrador", exist_ok=True)
# fig.savefig("../figures/004-nuevo_integrador/errors_Q_E_Lz_Radau_con_projection.png")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[17], line 34
#      30     )
#      31     for inc in [(90/N) * (i) for i in range(0, N+1)]
#      32 ]
#      33 Ps = [ics_i._get_period() for ics_i in ics_]
# ---> 34 paths = [
#      35     kerr.geodesic.get_path(ics_i, taus, integrator="Radau2").convert_to(
#      36         "BoyerLindquist", a=kerr.a
#      37     )
#
# File ~/Documents/Documentos/otros/relatipy/src/relatipy/numeric/geodesic/geodesic.py:284, in Geodesic.get_path(self, initial_conditions, taus, integrator, adaptative, steps_per_period, rtol, atol)
#     278     initial_conditions = initial_conditions.convert_to(
#     279         self.valid_coordinate, **self.metric.kwargs
#     280     )
#     282 ys0 = self.metric.get_4state_vector(initial_conditions)
# --> 284 sol = self._get_path_from_4state_vector(
#     285     ys0, taus, integrator=integrator, adaptative=adaptative,
#     286     steps_per_period=steps_per_period, period=period,
#     287     rtol=rtol, atol=atol,
#     288 )
#     290 dxs_dt = self.metric.get_dxs_dt_from_4velocity(sol[4:])
#     291 ys = coordinate_systems[initial_conditions.name_metric](
#     292     sol[:4], vels=dxs_dt[1:], from_dxs_dt=True, **initial_conditions.kwargs
#     293 )
#
# File ~/Documents/Documentos/otros/relatipy/src/relatipy/numeric/geodesic/geodesic.py:407, in Geodesic._get_path_from_4state_vector(self, ys0, taus, integrator, adaptative, steps_per_period, period, rtol, atol)
#     402 Q0 = p_th0 ** 2 + c2 * (
#     403     self.metric.a ** 2 * (1.0 - E0 ** 2) + Lz0 ** 2 / s2
#     404 )
#     406 t_eval_arg = None if adaptative else taus_np
# --> 407 result = _integrate_kerr_radau2_adaptive(
#     408     self.metric.R_s, self.metric.a,
#     409     ys0, t_span,
#     410     E0=E0, Lz0=Lz0, Q0=Q0,
#     411     rtol=rtol, atol=atol,
#     412     t_eval=t_eval_arg,
#     413 )
#     415 if adaptative:
#     416     return result.y
#
# File ~/Documents/Documentos/otros/relatipy/src/relatipy/numeric/geodesic/integrators/kerr/radau.py:418, in _integrate_kerr_radau2_adaptive(Rs, a, state0, tau_span, E0, Lz0, Q0, rtol, atol, t_eval, max_step, tol_proj, max_iter_proj)
#     415 if ret not in (0,):
#     416     msg = {-1: "max steps exceeded", -2: "Newton/LU failure",
#     417            -4: "step underflow"}.get(ret, f"error {ret}")
# --> 418     raise RuntimeError(f"kerr_radau2_adaptive: {msg}")
#     420 N = n_out.value
#     422 class _Result:
#
# RuntimeError: kerr_radau2_adaptive: max steps exceeded
